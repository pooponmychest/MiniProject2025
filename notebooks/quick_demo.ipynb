# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Folder where process_data.py saves processed CSVs
processed_dir = "../data/processed"

# List processed CSVs
files = [f for f in os.listdir(processed_dir) if f.endswith("_processed.csv")]
print("Available files:")
for i, f in enumerate(files, 1):
    print(f"{i}. {f}")
# Out:
# Available files:
# 1. AAPL_20250821_140419_processed.csv
# 2. ^GSPC_20250821_120744_processed.csv

# %%
# Pick a file by number
choice = int(input("Select file number: ")) - 1
file_name = files[choice]

# Load the file
df = pd.read_csv(os.path.join(processed_dir, file_name), parse_dates=["date"], index_col="date")
print(f"Loaded {file_name}")
df.head()
# Out:
# Select file number:  2
# Loaded ^GSPC_20250821_120744_processed.csv
#                   close         high          low         open      volume  \
# date
# 2024-08-21  5620.850098  5632.680176  5591.569824  5603.089844  3119670000
# 2024-08-22  5570.640137  5643.220215  5560.950195  5637.770020  2981530000
# 2024-08-23  5634.609863  5641.819824  5585.160156  5602.490234  3291940000
# 2024-08-26  5616.839844  5651.620117  5602.339844  5639.660156  2938570000
# 2024-08-27  5625.799805  5631.180176  5593.479980  5602.890137  2798990000
#
#             daily_return  sma_10  sma_50  vol_20
# date
# 2024-08-21           NaN     NaN     NaN     NaN
# 2024-08-22     -0.008933     NaN     NaN     NaN
# 2024-08-23      0.011483     NaN     NaN     NaN
# 2024-08-26     -0.003154     NaN     NaN     NaN
# 2024-08-27      0.001595     NaN     NaN     NaN

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["close"], label="Close")
plt.plot(df.index, df["sma_10"], label="SMA 10")
plt.plot(df.index, df["sma_50"], label="SMA 50")
plt.title("Stock Price with Moving Averages")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["vol_20"], label="20-day Volatility")
plt.title("Annualized Volatility")
plt.legend()
plt.show()
